# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from keras import Input,layers

# %%
input_tensor=Input((32,))#ağlar oluşturması
dense=layers.Dense(32,activation="relu")
output_tensor=dense(input_tensor)

# %%
from keras.models import Sequential,Model

# %%
from keras.src.layers.serialization import activation
#sequantial model
seq_model=Sequential()

seq_model.add(layers.Dense(32,activation="relu",input_shape=(64,)))
seq_model.add(layers.Dense(32,activation="relu"))
seq_model.add(layers.Dense(10,activation="softmax"))


seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 3466 (13.54 KB)
# Trainable params: 3466 (13.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#fun model
input_tensor=Input(shape=(64,))
x=layers.Dense(32,activation="relu")(input_tensor)


x=layers.Dense(32,activation="relu")(x)
output_tensor=layers.Dense(10,activation="softmax")(x)

model=Model(input_tensor,output_tensor)


model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64)]              0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 3466 (13.54 KB)
# Trainable params: 3466 (13.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#modelin derlenmesi
model.compile(optimizer="rmsprop",loss="categorical_crossentropy")

# %%
#model eğtimi
import numpy as np

# %%
x_train=np.random.random((1000,64))
y_train=np.random.random((1000,10))

# %%
#eğtim
model.fit(x_train
          ,y_train,epochs=10,batch_size=128)
score=model.evaluate(x_train
                     ,y_train)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 2s 6ms/step - loss: 11.9126
# Epoch 2/10
# 8/8 [==============================] - 0s 5ms/step - loss: 12.1152
# Epoch 3/10
# 8/8 [==============================] - 0s 5ms/step - loss: 12.6555
# Epoch 4/10
# 8/8 [==============================] - 0s 5ms/step - loss: 13.8185
# Epoch 5/10
# 8/8 [==============================] - 0s 4ms/step - loss: 15.9402
# Epoch 6/10
# 8/8 [==============================] - 0s 3ms/step - loss: 18.7885
# Epoch 7/10
# 8/8 [==============================] - 0s 3ms/step - loss: 22.4420
# Epoch 8/10
# 8/8 [==============================] - 0s 3ms/step - loss: 26.7628
# Epoch 9/10
# 8/8 [==============================] - 0s 3ms/step - loss: 31.7314
# Epoch 10/10
# 8/8 [==============================] - 0s 3ms/step - loss: 37.2751
# 32/32 [==============================] - 0s 2ms/step - loss: 40.7278
